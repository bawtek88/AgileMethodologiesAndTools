# %% [markdown]
# <a href="https://colab.research.google.com/github/bawtek88/AgileMethodologiesAndTools/blob/KTS-5-Jira-and-Github-integration-Part-2/testnotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test Notebook
# Simple notebook to verify that GitHub + Colab + Jupyter all load properly.

# %%
print("Hello world.")

# %%
x = 5
y = 7
x + y
print(x+y)
# Out:
# 12

# %% [markdown]
# **This is bold text using double asterisks.**
#
# __This is bold text using double underscores.__
